# %% [markdown]
# <a href="https://colab.research.google.com/github/chetankhairnar05/Python_Automation/blob/main/tables_from_pdf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task: you have pdf and write code to extract tables from pdf and save in xl files


#libraries : tabula or camelot(works well)


# First, you must install the required Python library.
# You also need to have Java installed on your system for tabula-py to work, as it's a wrapper for the Tabula-Java library.
# You can run this command in your terminal or a Colab cell:
# !pip install tabula-py pandas
# !pip install xlsxwriter

import pandas as pd
import tabula

# This URL points to a public PDF document with tables that are similar to the one you provided.
# It has a clear grid structure and is a good test case for the 'lattice' option.
pdf_url = "https://assets.accessible-digital-documents.com/uploads/2017/01/sample-tables.pdf"
output_filename = "extracted_tables.xlsx"

# --- Step 1: Read the tables from the PDF using a more robust method ---
# The 'lattice=True' parameter is crucial for tables with visible lines and merged cells.
# It uses the grid lines to define the cells, which is more reliable than the 'stream' method's whitespace-based parsing.
# You can also use the 'area' parameter to specify the coordinates of the table,
# for example: area=[top, left, bottom, right] to get even more precise results.
print(f"Extracting tables from PDF: {pdf_url}")
try:
    # Use lattice=True for tables with a clear grid structure.
    dfs = tabula.read_pdf(pdf_url, pages="all", multiple_tables=True, lattice=True)
    print(f"Successfully extracted {len(dfs)} tables.")
except Exception as e:
    print(f"Error extracting tables from the PDF: {e}")
    # An empty list is fine if no tables are found, but a more specific error is useful
    dfs = []

# --- Step 2: Process and Display the extracted DataFrames ---
if len(dfs) > 0:
    for i, df in enumerate(dfs):
        print(f"\n--- Table {i + 1} from the PDF ---")
        print(df.head()) # Print the first 5 rows of each extracted table

# --- Step 3: (Optional) Export all tables to a single Excel file on separate sheets ---
if len(dfs) > 0:
    try:
        with pd.ExcelWriter(output_filename, engine='xlsxwriter') as writer:
            for i, df in enumerate(dfs):
                sheet_name = f"Table_{i + 1}"
                # Handle potential MultiIndex columns
                if isinstance(df.columns, pd.MultiIndex):
                    # Flatten the MultiIndex columns into a single string for Excel
                    df.columns = ['_'.join(col).strip() if isinstance(col, tuple) else str(col) for col in df.columns.values]
                    df.columns = [col.replace('nan_', '').replace('_nan', '') for col in df.columns]

                df.to_excel(writer, sheet_name=sheet_name, index=False)
        print(f"\nSuccessfully exported all tables to '{output_filename}'.")
    except Exception as e:
        print(f"\nError exporting tables to Excel: {e}")

# --- Step 4: (Optional) Download the Excel file in a Colab environment ---
# This part is only for use in Google Colab. If you're running locally, you don't need this.
try:
    from google.colab import files
    print("Downloading the Excel file to your local machine.")
    files.download(output_filename)
except ImportError:
    print("\nNote: 'google.colab' module not found. This download step is skipped.")
# Out:
# Requirement already satisfied: tabula-py in /usr/local/lib/python3.11/dist-packages (2.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>1.24.4 in /usr/local/lib/python3.11/dist-packages (from tabula-py) (2.0.2)
# Requirement already satisfied: distro in /usr/local/lib/python3.11/dist-packages (from tabula-py) (1.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.11/dist-packages (3.2.5)
# Extracting tables from PDF: https://assets.accessible-digital-documents.com/uploads/2017/01/sample-tables.pdf
# WARNING:tabula.backend:Got stderr: Aug 07, 2025 10:52:36 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'Verdana'
# Aug 07, 2025 10:52:36 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Aug 07, 2025 10:52:36 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats
# Aug 07, 2025 10:52:36 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Times_Roman
# Aug 07, 2025 10:52:36 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif-Bold' for 'TimesNewRomanPS-BoldMT'
# Aug 07, 2025 10:52:36 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans-Bold' for 'TrebuchetMS-Bold'
# Aug 07, 2025 10:52:37 AM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSerif-Bold' for 'Georgia-Bold'
# Aug 07, 2025 10:52:37 AM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for Times_Roman
# Successfully extracted 29 tables.
#
# --- Table 1 from the PDF ---
#   Column header (TH) Column header (TH).1 Column header (TH).2
# 0    Row header (TH)       Data cell (TD)       Data cell (TD)
# 1     Row header(TH)       Data cell (TD)       Data cell (TD)
#
# --- Table 2 from the PDF ---
#   Expenditure by function £ million            2009/10  2010/11 1  Unnamed: 0
# 0                  Policy functions          Financial      22.50       30.57
# 1                               NaN      Information 2      10.20       14.80
# 2                               NaN        Contingency       2.60        1.20
# 3             Remunerated functions  Agency services 3      44.70       35.91
# 4                          Payments              22.41      19.88         NaN
#
# --- Table 3 from the PDF ---
#   Main character Daniel Radcliffe
# 0     Sidekick 1     Rupert Grint
# 1     Sidekick 2      Emma Watson
# 2   Lovable ogre  Robbie Coltrane
# 3      Professor     Maggie Smith
# 4     Headmaster   Richard Harris
#
# --- Table 4 from the PDF ---
#              Role             Actor
# 0  Main character  Daniel Radcliffe
# 1      Sidekick 1      Rupert Grint
# 2      Sidekick 2       Emma Watson
# 3    Lovable ogre   Robbie Coltrane
# 4       Professor      Maggie Smith
#
# --- Table 5 from the PDF ---
#            Unnamed: 0   2010   2009   2008
# 0  Non-current assets    NaN    NaN    NaN
# 1            Property  345.0  445.0  222.0
# 2          Investment  567.0  654.0  423.0
# 3         Intangibles  423.0  123.0  453.0
# 4      Current assets    NaN    NaN    NaN
#
# --- Table 6 from the PDF ---
#   Rainfall\r(inches)  Americas   Asia  Europe  Africa
# 0               2010       NaN    NaN     NaN     NaN
# 1            Average     104.0  201.0   193.0   144.0
# 2       24 hour high      15.0   26.0    27.0    18.0
# 3       12 hour high       9.0   10.0    11.0    12.0
# 4               2009       NaN    NaN     NaN     NaN
#
# --- Table 7 from the PDF ---
#   Non-current assets  2010  2009  2008
# 0           Property   345   445   222
# 1         Investment   567   654   423
# 2        Intangibles   423   123   453
#
# --- Table 8 from the PDF ---
#                 Current assets  2010  2009  2008
# 0  Trade and other receivables   435   634   231
# 1    Cash and cash equivalents   524   123   482
# 2                        Other   223   211   254
#
# --- Table 9 from the PDF ---
#   Rainfall (inches)  Americas  Asia  Europe  Africa
# 0           Average       133   244     155     166
# 1      24 hour high        27    28      29      20
# 2      12 hour high        11    12      13      16
#
# --- Table 10 from the PDF ---
#                Unnamed: 0       2011 2010 restated Unnamed: 1 Unnamed: 2
# 0          General income        NaN       250,000        NaN    200,000
# 1  Increase in value, WIP        NaN        15,000        NaN     30,000
# 2                     NaN        NaN       265,000        NaN    230,000
# 3    Administrative costs        NaN           NaN        NaN        NaN
# 4             Staff costs  (200,000)           NaN  (150,000)        NaN
#
# --- Table 11 from the PDF ---
#              Unnamed: 0               2011 2010 restated Unnamed: 1
# 0                Income     General income       250,000    200,000
# 1                   NaN  Increase in value        15,000     30,000
# 2                   NaN       Total income       265,000    230,000
# 3  Administrative costs        Staff costs     (200,000)  (150,000)
# 4                   NaN   Early departures      (10,000)   (20,000)
#
# --- Table 12 from the PDF ---
#   Unnamed: 0                                               2008  \
# 0       Name                                                Yes
# 1        Bob                                                  2
# 2        Sue                                                  3
# 3        Sam  [data relating to both columns in\ra single ce...
#
#                                                 2009 Unnamed: 1 Unnamed: 2  \
# 0                                                NaN         No        Yes
# 1                                                NaN          5          6
# 2                                                NaN          8          4
# 3  [data relating to both columns in\ra single ce...        NaN        NaN
#
#   Unnamed: 3
# 0         No
# 1          7
# 2          7
# 3        NaN
#
# --- Table 13 from the PDF ---
#                          Question Respondent A Respondent B Respondent C
# 0           Are you a UK citizen?                                    
# 1     Are you currently employed?                                    
# 2  Do you have a driving licence?                                    
#
# --- Table 14 from the PDF ---
#                          Question Respondent A Respondent B Respondent C
# 0           Are you a UK citizen?           No          Yes           No
# 1     Are you currently employed?          Yes           No          Yes
# 2  Do you have a driving licence?           No           No          Yes
#
# --- Table 15 from the PDF ---
#                 Unnamed: 0  2006  2007  2008  2009
# 0                Economics  A, B  A, C  A, B  A, C
# 1  International relations  A, E  A, E  A, B  A, E
# 2               Philosophy     A     A     A  A, D
# 3                 Politics  A, D  A, D  A, D     A
# 4              Mathematics  B, C     B  A, E  A, B
#
# --- Table 16 from the PDF ---
#                 Unnamed: 0 2006 2007 2008 2009
# 0                Economics   No  Yes  Yes  Yes
# 1  International relations   No   No   No   No
# 2               Philosophy   No   No   No   No
# 3                 Politics   No   No   No   No
# 4              Mathematics  Yes   No   No   No
#
# --- Table 17 from the PDF ---
#         Accounting item                    2011 Unnamed: 0
# 0                Income          General income    200,000
# 1                   NaN  Increase in value, WIP     30,000
# 2                   NaN         Income subtotal    230,000
# 3  Administrative costs                   Staff    150,000
# 4                   NaN        Early departures     20,000
#
# --- Table 18 from the PDF ---
#         Accounting item                    2011 Unnamed: 0
# 0                Income          General income    200,000
# 1                   NaN  Increase in value, WIP     30,000
# 2                   NaN         Income subtotal    230,000
# 3  Administrative costs                   Staff  (150,000)
# 4                   NaN        Early departures   (20,000)
#
# --- Table 19 from the PDF ---
#        Country  1980  1990  2000   2010
# 0  Afghanistan  0.78  1.48  2.16   3.33
# 1      Albania  8.89  9.67  9.89  10.38
# 2      Algeria  4.74  3.33  5.50   7.24
# 3      Andorra  4.98  5.63  9.09  10.35
# 4       Angola     -     -  4.42   4.42
#
# --- Table 20 from the PDF ---
#   Expenditure by function £million            2009/10  2010/11 1  Unnamed: 0
# 0                 Policy functions          Financial      22.50       30.57
# 1                              NaN      Information 2      10.20       14.80
# 2                              NaN        Contingency       2.60        1.20
# 3            Remunerated functions  Agency services 3      44.70       35.91
# 4                         Payments              22.41      19.88         NaN
#
# --- Table 21 from the PDF ---
#   Expenditure by function £million          2009/10  2010/11  Unnamed: 0
# 0                 Policy functions        Financial    22.50       30.57
# 1                              NaN      Information    10.20       14.80
# 2                              NaN      Contingency     2.60        1.20
# 3            Remunerated functions  Agency services    44.70       35.91
# 4                         Payments            22.41    19.88         NaN
#
# --- Table 22 from the PDF ---
#      Expenditure £m  Notes\r(Notes located on  page [n])   2010   2011
# 0       Information                                  1.0  10.20  14.80
# 1       Contingency                                  NaN   2.60   1.20
# 2          Payments                                  3.0  22.41  19.88
# 3  Banking services                                  4.0  22.90  44.23
# 4          Interest                                  NaN   0.23   0.10
#
# --- Table 23 from the PDF ---
#   Unnamed: 0     2008       2009 Unnamed: 1 Unnamed: 2
# 0       Name  Entered  Completed    Entered  Completed
# 1        Bob       22         21         20         19
# 2        Sue       44         12         12         10
#
# --- Table 24 from the PDF ---
#            Unnamed: 0   2010  Unnamed: 1   2009   2008
# 0  Non-current assets    NaN         NaN    NaN    NaN
# 1           Buildings  345.0         NaN  445.0  222.0
# 2          Investment  567.0         NaN  654.0  423.0
# 3         Intangibles  423.0         NaN  123.0  453.0
# 4      Current assets    NaN         NaN    NaN    NaN
#
# --- Table 25 from the PDF ---
#   Unnamed: 0     2008 2009 Unnamed: 1 Unnamed: 2
# 0       Name  Entered  Won    Entered        Won
# 1        Bob       22   21         20         19
# 2        Sue       44   12         12         10
# 3        Sam       16    4         45         30
#
# --- Table 26 from the PDF ---
#                 Unnamed: 0  2006  2007  2008  2009
# 0                Economics  A, B  A, C  A, C  A, C
# 1  International relations  A, E  A, E  A, B  A, B
# 2               Philosophy     A     A     A     A
# 3                 Politics  A, D  A, D  A, B     A
# 4              Mathematics  B, C     B  A, B  A, B
#
# --- Table 27 from the PDF ---
#                                    Name  Apples  Pears
# 0                             Bob Scott      20     25
# 1  Susan. P. Arnold-Jones, BA, FRSA, MD      24     15
# 2                  Sam Holder-Dickinson      14     10
#
# --- Table 28 from the PDF ---
#            Unnamed: 0   2010   2009   2008
# 0  Non-current assets    NaN    NaN    NaN
# 1           Buildings  345.0  445.0  222.0
# 2          Investment  567.0  654.0  423.0
# 3         Intangibles  423.0  123.0  453.0
# 4      Current assets    NaN    NaN    NaN
#
# --- Table 29 from the PDF ---
#             Unnamed: 0 South America   Asia  Africa  Australia
# 0                 2010           NaN    NaN     NaN        NaN
# 1      Highest average         523.6  467.4   405.0      340.5
# 2  Highest in 24 hours          73.1   54.1    27.2       66.3
# 3  Highest in 12 hours         42 .4   30.1    15.9       40.3
# 4                 2009           NaN    NaN     NaN        NaN
#
# Successfully exported all tables to 'extracted_tables.xlsx'.
# Downloading the Excel file to your local machine.

# %%
# First, you must install the required Python libraries and their dependencies.
# You will need to install ghostscript, which is a dependency for camelot.
# On Linux (e.g., in a Colab environment), you can install it like this:
# !apt-get install ghostscript
# On Windows, you need to install it separately from the official Ghostscript website.
#
# Then, install the Python libraries:
# !pip install camelot-py[cv] pandas
# !pip install xlsxwriter

import pandas as pd
import camelot

# This URL points to a public PDF document with tables.
pdf_url = "https://assets.accessible-digital-documents.com/uploads/2017/01/sample-tables.pdf"
output_filename = "extracted_tables.xlsx"

# --- Step 1: Read the tables from the PDF using camelot ---
# We'll use the 'lattice' flavor since the table in your example has clear lines.
# The 'pages="all"' parameter tells camelot to process all pages in the PDF.
print(f"Extracting tables from PDF using Camelot: {pdf_url}")
try:
    # Use flavor='lattice' for tables with a clear grid structure.
    tables = camelot.read_pdf(pdf_url, pages="all", flavor='lattice')
    print(f"Successfully extracted {tables.n} tables.")
except Exception as e:
    print(f"Error extracting tables from the PDF: {e}")
    tables = []

# --- Step 2: Process and Display the extracted DataFrames ---
if tables:
    for i, table in enumerate(tables):
        df = table.df # Get the DataFrame from the Camelot table object
        print(f"\n--- Table {i + 1} from the PDF ---")
        print(df.head()) # Print the first 5 rows of each extracted table

# --- Step 3: (Optional) Export all tables to a single Excel file on separate sheets ---
if tables:
    try:
        with pd.ExcelWriter(output_filename, engine='xlsxwriter') as writer:
            for i, table in enumerate(tables):
                df = table.df # Get the DataFrame from the Camelot table object
                sheet_name = f"Table_{i + 1}"
                # Handle potential MultiIndex columns
                if isinstance(df.columns, pd.MultiIndex):
                    df.columns = ['_'.join(col).strip() if isinstance(col, tuple) else str(col) for col in df.columns.values]
                    df.columns = [col.replace('nan_', '').replace('_nan', '') for col in df.columns]

                df.to_excel(writer, sheet_name=sheet_name, index=False)
        print(f"\nSuccessfully exported all tables to '{output_filename}'.")
    except Exception as e:
        print(f"\nError exporting tables to Excel: {e}")

# --- Step 4: (Optional) Download the Excel file in a Colab environment ---
# This part is only for use in Google Colab. If you're running locally, you don't need this.
try:
    from google.colab import files
    print("Downloading the Excel file to your local machine.")
    files.download(output_filename)
except ImportError:
    print("\nNote: 'google.colab' module not found. This download step is skipped.")
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Collecting camelot-py[cv]
#   Downloading camelot_py-1.0.0-py3-none-any.whl.metadata (9.4 kB)
# WARNING: camelot-py 1.0.0 does not provide the extra 'cv'
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.11/dist-packages (from camelot-py[cv]) (8.2.1)
# Requirement already satisfied: chardet>=5.1.0 in /usr/local/lib/python3.11/dist-packages (from camelot-py[cv]) (5.2.0)
# Requirement already satisfied: numpy>=1.24.4 in /usr/local/lib/python3.11/dist-packages (from camelot-py[cv]) (2.0.2)
# Requirement already satisfied: openpyxl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from camelot-py[cv]) (3.1.5)
# Collecting pdfminer-six>=20240706 (from camelot-py[cv])
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Collecting pypdf<4.0,>=3.17 (from camelot-py[cv])
#   Downloading pypdf-3.17.4-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from camelot-py[cv]) (0.9.0)
# Requirement already satisfied: opencv-python-headless>=4.7.0.68 in /usr/local/lib/python3.11/dist-packages (from camelot-py[cv]) (4.12.0.88)
# Collecting pypdfium2>=4 (from camelot-py[cv])
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.1.0->camelot-py[cv]) (2.0.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer-six>=20240706->camelot-py[cv]) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer-six>=20240706->camelot-py[cv]) (43.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py[cv]) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer-six>=20240706->camelot-py[cv]) (2.22)
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 58.8 MB/s eta 0:00:00
# Downloading pypdf-3.17.4-py3-none-any.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.1 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 94.5 MB/s eta 0:00:00
# Downloading camelot_py-1.0.0-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.6/66.6 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pypdf, pdfminer-six, camelot-py
# Successfully installed camelot-py-1.0.0 pdfminer-six-20250506 pypdf-3.17.4 pypdfium2-4.30.0
# Requirement already satisfied: xlsxwriter in /usr/local/lib/python3.11/dist-packages (3.2.5)
# /usr/local/lib/python3.11/dist-packages/pypdf/_crypt_providers/_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from this module in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4
# Extracting tables from PDF using Camelot: https://assets.accessible-digital-documents.com/uploads/2017/01/sample-tables.pdf
# Successfully extracted 28 tables.
#
# --- Table 1 from the PDF ---
#                                    0                  1        2          3
# 0  Expenditure by function £ million                     2009/10  2010/11 1
# 1                   Policy functions          Financial     22.5      30.57
# 2                                         Information 2     10.2       14.8
# 3                                           Contingency      2.6        1.2
# 4              Remunerated functions  Agency services 3     44.7      35.91
#
# --- Table 2 from the PDF ---
#                                   0                        1
# 0  Main character  Daniel Radcliffe
# 1                        Sidekick 1             Rupert Grint
# 2                        Sidekick 2              Emma Watson
# 3                      Lovable ogre          Robbie Coltrane
# 4                                    Professor  Maggie Smith
#
# --- Table 3 from the PDF ---
#                                   0                1
# 0                                      Role    Actor
# 1  Main character  Daniel Radcliffe
# 2                        Sidekick 1     Rupert Grint
# 3                        Sidekick 2      Emma Watson
# 4                      Lovable ogre  Robbie Coltrane
#
# --- Table 4 from the PDF ---
#                                0
# 0             2010 \n2009 \n2008
# 1             Non-current assets
# 2     Property \n345 \n445 \n222
# 3   Investment \n567 \n654 \n423
# 4  Intangibles \n423 \n123 \n453
#
# --- Table 5 from the PDF ---
#                                                    0
# 0  Rainfall \nAmericas \nAsia \nEurope \nAfrica \...
# 1                                               2010
# 2                    Average \n104 \n201 \n193 \n144
# 3                   24 hour high \n15 \n26 \n27 \n18
# 4                    12 hour high \n9 \n10 \n11 \n12
#
# --- Table 6 from the PDF ---
#                     0     1     2     3
# 0  Non-current assets  2010  2009  2008
# 1            Property   345   445   222
# 2          Investment   567   654   423
# 3         Intangibles   423   123   453
#
# --- Table 7 from the PDF ---
#                              0     1     2     3
# 0               Current assets  2010  2009  2008
# 1  Trade and other receivables   435   634   231
# 2    Cash and cash equivalents   524   123   482
# 3                        Other   223   211   254
#
# --- Table 8 from the PDF ---
#                    0         1     2       3       4
# 0  Rainfall (inches)  Americas  Asia  Europe  Africa
# 1            Average       133   244     155     166
# 2       24 hour high        27    28      29      20
# 3       12 hour high        11    12      13      16
#
# --- Table 9 from the PDF ---
#                         0        1 2              3 4
# 0                             2011    2010 restated
# 1          General income  250,000          200,000
# 2  Increase in value, WIP   15,000           30,000
# 3                          265,000          230,000
# 4    Administrative costs
#
# --- Table 10 from the PDF ---
#                       0                  1          2              3
# 0                                                2011  2010 restated
# 1                Income     General income    250,000        200,000
# 2                        Increase in value     15,000         30,000
# 3                             Total income    265,000        230,000
# 4  Administrative costs        Staff costs  (200,000)      (150,000)
#
# --- Table 11 from the PDF ---
#       0                                                  1  \
# 0                                                     2008
# 1  Name                                           Yes \nNo
# 2   Bob                                              2 \n5
# 3   Sue                                              3 \n8
# 4   Sam  [data relating to both columns in \na single c...
#
#                                                    2
# 0                                               2009
# 1                                           Yes \nNo
# 2                                              6 \n7
# 3                                              4 \n7
# 4  [data relating to both columns in \na single c...
#
# --- Table 12 from the PDF ---
#                                 0             1             2             3
# 0                        Question  Respondent A  Respondent B  Respondent C
# 1           Are you a UK citizen?                                       
# 2     Are you currently employed?                                       
# 3  Do you have a driving licence?                                       
#
# --- Table 13 from the PDF ---
#                                 0             1             2             3
# 0                        Question  Respondent A  Respondent B  Respondent C
# 1           Are you a UK citizen?            No           Yes            No
# 2     Are you currently employed?           Yes            No           Yes
# 3  Do you have a driving licence?            No            No           Yes
#
# --- Table 14 from the PDF ---
#                          0     1     2     3     4
# 0                           2006  2007  2008  2009
# 1                Economics  A, B  A, C  A, B  A, C
# 2  International relations  A, E  A, E  A, B  A, E
# 3               Philosophy     A     A     A  A, D
# 4                 Politics  A, D  A, D  A, D     A
#
# --- Table 15 from the PDF ---
#                          0     1     2     3     4
# 0                           2006  2007  2008  2009
# 1                Economics    No   Yes   Yes   Yes
# 2  International relations    No    No    No    No
# 3               Philosophy    No    No    No    No
# 4                 Politics    No    No    No    No
#
# --- Table 16 from the PDF ---
#                       0                       1        2
# 0       Accounting item                             2011
# 1                        Income  General income  200,000
# 2                        Increase in value, WIP   30,000
# 3                               Income subtotal  230,000
# 4  Administrative costs                   Staff  150,000
#
# --- Table 17 from the PDF ---
#                       0                       1          2
# 0       Accounting item                               2011
# 1                        Income  General income    200,000
# 2                        Increase in value, WIP     30,000
# 3                               Income subtotal    230,000
# 4  Administrative costs                   Staff  (150,000)
#
# --- Table 18 from the PDF ---
#              0     1     2     3      4
# 0      Country  1980  1990  2000   2010
# 1  Afghanistan  0.78  1.48  2.16   3.33
# 2      Albania  8.89  9.67  9.89  10.38
# 3      Algeria  4.74  3.33  5.50   7.24
# 4      Andorra  4.98  5.63  9.09  10.35
#
# --- Table 19 from the PDF ---
#                                   0                  1        2            3
# 0  Expenditure by function £million                     2009/10  1 \n2010/11
# 1                  Policy functions          Financial     22.5        30.57
# 2                                      2 \nInformation     10.2         14.8
# 3                                          Contingency      2.6          1.2
# 4             Remunerated functions  Agency services 3     44.7        35.91
#
# --- Table 20 from the PDF ---
#                                   0                1        2        3
# 0  Expenditure by function £million                   2009/10  2010/11
# 1                  Policy functions        Financial     22.5    30.57
# 2                                        Information     10.2     14.8
# 3                                        Contingency      2.6      1.2
# 4             Remunerated functions  Agency services     44.7    35.91
#
# --- Table 21 from the PDF ---
#                   0                                      1      2      3
# 0    Expenditure £m  Notes  \n(Notes located on  page [n])   2010   2011
# 1       Information                                      1   10.2   14.8
# 2       Contingency                                           2.6    1.2
# 3          Payments                                      3  22.41  19.88
# 4  Banking services                                      4  22.90  44.23
#
# --- Table 22 from the PDF ---
#       0        1          2        3          4
# 0           2008                2009
# 1  Name  Entered  Completed  Entered  Completed
# 2   Bob       22         21       20         19
# 3   Sue       44         12       12         10
#
# --- Table 23 from the PDF ---
#                                0
# 0             2010 \n2009 \n2008
# 1             Non-current assets
# 2    Buildings \n345 \n445 \n222
# 3   Investment \n567 \n654 \n423
# 4  Intangibles \n423 \n123 \n453
#
# --- Table 24 from the PDF ---
#       0        1    2        3    4
# 0           2008          2009
# 1  Name  Entered  Won  Entered  Won
# 2   Bob       22   21       20   19
# 3   Sue       44   12       12   10
# 4   Sam       16    4       45   30
#
# --- Table 25 from the PDF ---
#                          0     1     2     3     4
# 0                           2006  2007  2008  2009
# 1                Economics  A, B  A, C  A, C  A, C
# 2  International relations  A, E  A, E  A, B  A, B
# 3               Philosophy     A     A     A     A
# 4                 Politics  A, D  A, D  A, B     A
#
# --- Table 26 from the PDF ---
#                                       0       1      2
# 0                                  Name  Apples  Pears
# 1                             Bob Scott      20     25
# 2  Susan. P. Arnold-Jones, BA, FRSA, MD      24     15
# 3                  Sam Holder-Dickinson      14     10
#
# --- Table 27 from the PDF ---
#                                0
# 0             2010 \n2009 \n2008
# 1             Non-current assets
# 2    Buildings \n345 \n445 \n222
# 3   Investment \n567 \n654 \n423
# 4  Intangibles \n423 \n123 \n453
#
# --- Table 28 from the PDF ---
#                                                  0
# 0        South America \nAsia \nAfrica \nAustralia
# 1                                             2010
# 2  Highest average \n523.6 \n467.4 \n405.0 \n340.5
# 3  Highest in 24 hours \n73.1 \n54.1 \n27.2 \n66.3
# 4  Highest in 12 hours \n42.4 \n30.1 \n15.9 \n40.3
#
# Successfully exported all tables to 'extracted_tables.xlsx'.
# Downloading the Excel file to your local machine.
